# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamalproject/DSA/blob/main/DSA_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text1=input()
text2=input()

text1=text1.lower()
text2=text2.lower()

if(text1<text2 and text1 in text2):
  print(text1,end="")
elif(text2<text1 and text2 in text1):
  print(text2,end="")
else:
  print("None")
# Out:
# kamal
# kamallochanpanigrahi
# k
# a
# a
# a
# a
# a
# m
# a
# a
# a
# a
# a
# l
# l
