# %% [markdown]
# <a href="https://colab.research.google.com/github/Kamalproject/DSA/blob/main/DSA_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text1=input()
text2=input()

text1=text1.lower()
text2=text2.lower()

for i in text1:
    if(i in text2 and text2>text1):
      print(i, end="")
for j in text2:
  if(j in text2 and text2<text1):
    print(j,end="")
# Out:
# kamal
# kamallochan
# kaaamaaall
